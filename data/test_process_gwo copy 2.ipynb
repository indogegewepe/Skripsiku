# %%
import copy
import numpy as np
import pandas as pd
import json
from datetime import datetime
from collections import defaultdict
import random

# Fungsi konversi waktu ke menit
def time_to_minutes(t):
    try:
        dt = datetime.strptime(t, "%H:%M:%S")
    except ValueError:
        dt = datetime.strptime(t, "%H:%M")
    return dt.hour * 60 + dt.minute

# Inisialisasi Data
dosen_df = pd.read_csv('data_skripsi_dosen.csv')
mk_genap_df = pd.read_csv('data_skripsi_mk_genap.csv')
data_dosen_df = pd.read_csv('data_skripsi_data_dosen.csv')
hari_df = pd.read_csv('data_skripsi_hari.csv')
ruang_df = pd.read_csv('data_skripsi_ruang.csv')
jam_df = pd.read_csv('data_skripsi_jam.csv')

# Urutkan jam_df sebelum generate slot
jam_df = jam_df.sort_values('id_jam')

# Gabungkan data menggunakan merge
merged_df = pd.merge(
    pd.merge(data_dosen_df, dosen_df, on='id_dosen'),
    mk_genap_df, on='id_mk_genap'
)

# Tambahkan temporary id secara unik untuk setiap baris di merged_df
merged_df['temp_id'] = range(1, len(merged_df) + 1)

# Cek beberapa baris untuk memastikan id sudah ditambahkan
print(merged_df)
# Out:
#      id_dosen  id_mk_genap kelas                             nama_dosen  \
# 0           2    211840231     A            Ahmad Azhari, S.Kom., M.Eng
# 1           2    211861331     A            Ahmad Azhari, S.Kom., M.Eng
# 2           2    211861431     A            Ahmad Azhari, S.Kom., M.Eng
# 3           3    211840131     A               Ali Tarmuji, S.T., M.Cs.
# 4           3    211860330     A               Ali Tarmuji, S.T., M.Cs.
# ..        ...          ...   ...                                    ...
# 102        36    211820911     E           Wahyu Pujiyono, Drs., M.Kom.
# 103        37    211860531     B          Prof. Imam Riadi, Dr., M.Kom.
# 104        38    211860220     G        Prof. Sunardi, S.T., M.T., Ph.D
# 105        39    211860220     H   Prof. Abdul Fadlil, Drs., M.T., Ph.D
# 106        40    211840531     D  Prof. Anton Yudhana, S.T., M.T., Ph.D
#
#                                 nama_mk_genap  smt  sks    sifat kategori  \
# 0                            Grafika Komputer    4    3    Wajib        -
# 1                  Pengembangan Aplikasi Game    6    3  Pilihan       SC
# 2                            Pengenalan Pola     6    3  Pilihan       SC
# 3    Analisis dan Perancangan Perangkat Lunak    4    3    Wajib        -
# 4                    Rekayasa Perangkat Lunak    6    3    Wajib        -
# ..                                        ...  ...  ...      ...      ...
# 102           Praktikum Algoritma Pemrograman    2    1    Wajib        -
# 103                        Keamanan Informasi    6    3  Pilihan   Relata
# 104                     Metodologi Penelitian    6    2    Wajib        -
# 105                     Metodologi Penelitian    6    2    Wajib        -
# 106                         Kecerdasan Buatan    4    3    Wajib        -
#
#       metode  temp_id
# 0    Offline        1
# 1    Offline        2
# 2     Online        3
# 3    Offline        4
# 4    Offline        5
# ..       ...      ...
# 102  Offline      103
# 103   Online      104
# 104   Online      105
# 105   Online      106
# 106  Offline      107
#
# [107 rows x 11 columns]

# %% [markdown]
# Tahapan GWO
#
# 1. Preprocessing
#
#     Membangun struktur slot waktu.
#
# 2. Inisialisasi Populasi (GWO)
#
#
#     Inisialisasi populasi serigala acak (Xi).
#
#     Setiap "serigala" dalam GWO mewakili solusi penjadwalan yang mungkin (misalnya: variasi pengaturan slot).
#
# 3. Fitness Function (GWO)
#     Hitung nilai fitness untuk setiap serigala.
#
#     Mengevaluasi kualitas penjadwalan (misalnya: minimalisasi konflik, kepadatan ruang, dll).
#
# 4. Proses Optimasi (GWO)
#     Tentukan Alpha, Beta, dan Delta berdasarkan nilai fitness.
#
#     Menggunakan hierarki Alpha, Beta, Delta untuk memperbarui posisi solusi.
#
#     While (iterasi < maksimum iterasi):
#       1. Perbarui parameter a, A, dan C.
#       2. For setiap serigala:
#           1. Perbarui posisi serigala berdasarkan Alpha, Beta, dan Delta.
#       3. Hitung nilai fitness untuk setiap serigala.
#       4. Perbarui Alpha, Beta, dan Delta.
# 5. Postprocessing
#     Return solusi terbaik (Alpha).
#
#     Menampilkan jadwal terbaik hasil optimasi.

# %%
# @title Preprosessing
# Generator slot jadwal
def slot_generator():
    slots = []
    id_counter = 1
    for hari in hari_df['nama_hari']:
        for ruang in ruang_df['nama_ruang']:
            for jam in jam_df.itertuples():
                slots.append({
                    "id_slot": id_counter,
                    "id_mk": None,
                    "mata_kuliah": None,
                    "id_dosen": None,
                    "dosen": None,
                    "ruang": ruang,
                    "hari": hari,
                    "jam_mulai": jam.jam_awal,
                    "jam_selesai": jam.jam_akhir,
                    "kelas": None,
                    "sks": None,
                    "metode": None,
                    "temp_id": None  # Akan diisi jika slot terisi course
                })
                id_counter += 1
    return slots

slots = slot_generator()
print("5 slot pertama:")
for slot in slots[:5]:
    print(slot)
    
print("\n5 slot terakhir:")
for slot in slots[-5:]:
    print(slot)
# Out:
# 5 slot pertama:
# {'id_slot': 1, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Senin', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 2, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Senin', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 3, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Senin', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 4, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Senin', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 5, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Senin', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
#
# 5 slot terakhir:
# {'id_slot': 500, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Sabtu', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 501, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Sabtu', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 502, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Sabtu', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 503, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Sabtu', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 504, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Sabtu', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}

# %%
# Fungsi utama: buat jadwal acak dengan penempatan blok course berdasarkan SKS
def create_random_schedule(ordered_courses_df=None):
    schedule = slot_generator()
    if ordered_courses_df is None:
        merged_shuffled = merged_df.sample(frac=1).iterrows()
    else:
        merged_shuffled = ordered_courses_df.iterrows()
    
    # Tracking alokasi (untuk referensi)
    room_allocations = defaultdict(list)
    teacher_allocations = defaultdict(list)
    class_allocations = defaultdict(list)
    
    for _, row in merged_shuffled:
        id_mk = row['id_mk_genap']
        mata_kuliah = row['nama_mk_genap']
        id_dosen = row['id_dosen']
        dosen = row['nama_dosen']
        kelas = row['kelas']
        sks = int(row['sks'])
        metode = row['metode']
        temp_id = row['temp_id']  # temporary id course
        
        possible_positions = list(range(len(schedule) - sks + 1))
        random.shuffle(possible_positions)
        
        candidate_blocks = []
        for i in possible_positions:
            block = schedule[i:i+sks]
            if not all(slot['mata_kuliah'] is None for slot in block) or not all(slot['hari'] == block[0]['hari'] for slot in block):
                continue
            if not all(slot['ruang'] == block[0]['ruang'] for slot in block):
                continue
            hari = block[0]['hari']
            ruang = block[0]['ruang']
            time_block = (time_to_minutes(block[0]['jam_mulai']), time_to_minutes(block[-1]['jam_selesai']))
            kelas_already = len(class_allocations[(kelas, hari)]) > 0
            candidate_blocks.append((block, time_block, kelas_already))
        
        if candidate_blocks:
            selected_block = candidate_blocks[0][0]
            for slot in selected_block:
                slot.update({
                    "id_mk": id_mk,
                    "mata_kuliah": mata_kuliah,
                    "id_dosen": id_dosen,
                    "dosen": dosen,
                    "kelas": kelas,
                    "sks": sks,
                    "metode": metode,
                    "temp_id": temp_id
                })
            hari = selected_block[0]['hari']
            ruang = selected_block[0]['ruang']
            time_block = (time_to_minutes(selected_block[0]['jam_mulai']),
                          time_to_minutes(selected_block[-1]['jam_selesai']))
            room_allocations[(ruang, hari)].append(time_block)
            teacher_allocations[(dosen, hari)].append(time_block)
            class_allocations[(kelas, hari)].append(time_block)
        else:
            print(f"Gagal menempatkan: {kelas} - {mata_kuliah} - {dosen}")
    
    return schedule

# Contoh penggunaan:
population_size = 1
population = [create_random_schedule() for _ in range(population_size)]

# Uncomment untuk menampilkan jadwal
i=0
for schedule in population:
    for slot in schedule:
        print(slot)
        if slot['mata_kuliah'] is not None:
            i+=1
        # print(slot)
    if i == merged_df.sum()['sks']:
        print("Jadwal Sudah Lengkap")
    else:
        print("Jadwal Belum Lengkap")

print("Jumlah slot yang terisi: ", i)
# Out:
# {'id_slot': 1, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Senin', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 2, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Senin', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 3, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Senin', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 4, 'id_mk': 211860120, 'mata_kuliah': 'Manajemen Proyek Teknologi Informasi', 'id_dosen': 32, 'dosen': 'Sri Winiarti, S.T., M.Cs.', 'ruang': '4.1.5.55', 'hari': 'Senin', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': 'G', 'sks': 2, 'metode': 'Online', 'temp_id': 89}
# {'id_slot': 5, 'id_mk': 211860120, 'mata_kuliah': 'Manajemen Proyek Teknologi Informasi', 'id_dosen': 32, 'dosen': 'Sri Winiarti, S.T., M.Cs.', 'ruang': '4.1.5.55', 'hari': 'Senin', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': 'G', 'sks': 2, 'metode': 'Online', 'temp_id': 89}
# {'id_slot': 6, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Senin', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 7, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Senin', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 8, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Senin', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 9, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Senin', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 10, 'id_mk': 211840231, 'mata_kuliah': 'Grafika Komputer', 'id_dosen': 22, 'dosen': 'Miftahurrahma Rosyda, S.Kom., M.Eng', 'ruang': '4.1.5.55', 'hari': 'Senin', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 60}
# {'id_slot': 11, 'id_mk': 211840231, 'mata_kuliah': 'Grafika Komputer', 'id_dosen': 22, 'dosen': 'Miftahurrahma Rosyda, S.Kom., M.Eng', 'ruang': '4.1.5.55', 'hari': 'Senin', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 60}
# {'id_slot': 12, 'id_mk': 211840231, 'mata_kuliah': 'Grafika Komputer', 'id_dosen': 22, 'dosen': 'Miftahurrahma Rosyda, S.Kom., M.Eng', 'ruang': '4.1.5.55', 'hari': 'Senin', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 60}
# {'id_slot': 13, 'id_mk': 211820631, 'mata_kuliah': 'Matematika Diskrit', 'id_dosen': 18, 'dosen': 'Herman Yuliansyah, S.T., M.Eng.', 'ruang': '4.1.5.57', 'hari': 'Senin', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 47}
# {'id_slot': 14, 'id_mk': 211820631, 'mata_kuliah': 'Matematika Diskrit', 'id_dosen': 18, 'dosen': 'Herman Yuliansyah, S.T., M.Eng.', 'ruang': '4.1.5.57', 'hari': 'Senin', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 47}
# {'id_slot': 15, 'id_mk': 211820631, 'mata_kuliah': 'Matematika Diskrit', 'id_dosen': 18, 'dosen': 'Herman Yuliansyah, S.T., M.Eng.', 'ruang': '4.1.5.57', 'hari': 'Senin', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 47}
# {'id_slot': 16, 'id_mk': 211860330, 'mata_kuliah': 'Rekayasa Perangkat Lunak', 'id_dosen': 7, 'dosen': 'Ardi Pujiyanta, Dr., Ir., M.T.', 'ruang': '4.1.5.57', 'hari': 'Senin', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 16}
# {'id_slot': 17, 'id_mk': 211860330, 'mata_kuliah': 'Rekayasa Perangkat Lunak', 'id_dosen': 7, 'dosen': 'Ardi Pujiyanta, Dr., Ir., M.T.', 'ruang': '4.1.5.57', 'hari': 'Senin', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 16}
# {'id_slot': 18, 'id_mk': 211860330, 'mata_kuliah': 'Rekayasa Perangkat Lunak', 'id_dosen': 7, 'dosen': 'Ardi Pujiyanta, Dr., Ir., M.T.', 'ruang': '4.1.5.57', 'hari': 'Senin', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 16}
# {'id_slot': 19, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.57', 'hari': 'Senin', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 20, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.57', 'hari': 'Senin', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 21, 'id_mk': 211860220, 'mata_kuliah': 'Metodologi Penelitian', 'id_dosen': 6, 'dosen': 'Ardiansyah, Dr., S.T., M.Cs.', 'ruang': '4.1.5.57', 'hari': 'Senin', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': 'A', 'sks': 2, 'metode': 'Online', 'temp_id': 10}
# {'id_slot': 22, 'id_mk': 211860220, 'mata_kuliah': 'Metodologi Penelitian', 'id_dosen': 6, 'dosen': 'Ardiansyah, Dr., S.T., M.Cs.', 'ruang': '4.1.5.57', 'hari': 'Senin', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': 'A', 'sks': 2, 'metode': 'Online', 'temp_id': 10}
# {'id_slot': 23, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.57', 'hari': 'Senin', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 24, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.57', 'hari': 'Senin', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 25, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.59', 'hari': 'Senin', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 26, 'id_mk': 211820731, 'mata_kuliah': 'Pemrograman Web', 'id_dosen': 18, 'dosen': 'Herman Yuliansyah, S.T., M.Eng.', 'ruang': '4.1.5.59', 'hari': 'Senin', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 48}
# {'id_slot': 27, 'id_mk': 211820731, 'mata_kuliah': 'Pemrograman Web', 'id_dosen': 18, 'dosen': 'Herman Yuliansyah, S.T., M.Eng.', 'ruang': '4.1.5.59', 'hari': 'Senin', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 48}
# {'id_slot': 28, 'id_mk': 211820731, 'mata_kuliah': 'Pemrograman Web', 'id_dosen': 18, 'dosen': 'Herman Yuliansyah, S.T., M.Eng.', 'ruang': '4.1.5.59', 'hari': 'Senin', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 48}
# {'id_slot': 29, 'id_mk': 211860931, 'mata_kuliah': 'Sistem terdistribusi', 'id_dosen': 27, 'dosen': 'Muslihudin, S.T., M.T.', 'ruang': '4.1.5.59', 'hari': 'Senin', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': 'A', 'sks': 3, 'metode': 'Online', 'temp_id': 73}
# {'id_slot': 30, 'id_mk': 211860931, 'mata_kuliah': 'Sistem terdistribusi', 'id_dosen': 27, 'dosen': 'Muslihudin, S.T., M.T.', 'ruang': '4.1.5.59', 'hari': 'Senin', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': 'A', 'sks': 3, 'metode': 'Online', 'temp_id': 73}
# {'id_slot': 31, 'id_mk': 211860931, 'mata_kuliah': 'Sistem terdistribusi', 'id_dosen': 27, 'dosen': 'Muslihudin, S.T., M.T.', 'ruang': '4.1.5.59', 'hari': 'Senin', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': 'A', 'sks': 3, 'metode': 'Online', 'temp_id': 73}
# {'id_slot': 32, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.59', 'hari': 'Senin', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 33, 'id_mk': 211840131, 'mata_kuliah': 'Analisis dan Perancangan Perangkat Lunak', 'id_dosen': 25, 'dosen': 'Murein Miksa Mardhia, S.T., M.T.', 'ruang': '4.1.5.59', 'hari': 'Senin', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': 'D', 'sks': 3, 'metode': 'Offline', 'temp_id': 64}
# {'id_slot': 34, 'id_mk': 211840131, 'mata_kuliah': 'Analisis dan Perancangan Perangkat Lunak', 'id_dosen': 25, 'dosen': 'Murein Miksa Mardhia, S.T., M.T.', 'ruang': '4.1.5.59', 'hari': 'Senin', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': 'D', 'sks': 3, 'metode': 'Offline', 'temp_id': 64}
# {'id_slot': 35, 'id_mk': 211840131, 'mata_kuliah': 'Analisis dan Perancangan Perangkat Lunak', 'id_dosen': 25, 'dosen': 'Murein Miksa Mardhia, S.T., M.T.', 'ruang': '4.1.5.59', 'hari': 'Senin', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': 'D', 'sks': 3, 'metode': 'Offline', 'temp_id': 64}
# {'id_slot': 36, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.59', 'hari': 'Senin', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 37, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.60', 'hari': 'Senin', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 38, 'id_mk': 211840831, 'mata_kuliah': 'Strategi Algoritma', 'id_dosen': 13, 'dosen': 'Dwi Normawati, S.T., M.Eng', 'ruang': '4.1.5.60', 'hari': 'Senin', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 33}
# {'id_slot': 39, 'id_mk': 211840831, 'mata_kuliah': 'Strategi Algoritma', 'id_dosen': 13, 'dosen': 'Dwi Normawati, S.T., M.Eng', 'ruang': '4.1.5.60', 'hari': 'Senin', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 33}
# {'id_slot': 40, 'id_mk': 211840831, 'mata_kuliah': 'Strategi Algoritma', 'id_dosen': 13, 'dosen': 'Dwi Normawati, S.T., M.Eng', 'ruang': '4.1.5.60', 'hari': 'Senin', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 33}
# {'id_slot': 41, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.60', 'hari': 'Senin', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 42, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.60', 'hari': 'Senin', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 43, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.60', 'hari': 'Senin', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 44, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.60', 'hari': 'Senin', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 45, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.60', 'hari': 'Senin', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 46, 'id_mk': 211860120, 'mata_kuliah': 'Manajemen Proyek Teknologi Informasi', 'id_dosen': 17, 'dosen': 'Guntur  Maulana Zamroni, B.Sc., M.Kom.', 'ruang': '4.1.5.60', 'hari': 'Senin', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': 'C', 'sks': 2, 'metode': 'Online', 'temp_id': 46}
# {'id_slot': 47, 'id_mk': 211860120, 'mata_kuliah': 'Manajemen Proyek Teknologi Informasi', 'id_dosen': 17, 'dosen': 'Guntur  Maulana Zamroni, B.Sc., M.Kom.', 'ruang': '4.1.5.60', 'hari': 'Senin', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': 'C', 'sks': 2, 'metode': 'Online', 'temp_id': 46}
# {'id_slot': 48, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.60', 'hari': 'Senin', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 49, 'id_mk': 211840330, 'mata_kuliah': 'Interaksi Manusia dan Komputer', 'id_dosen': 13, 'dosen': 'Dwi Normawati, S.T., M.Eng', 'ruang': '4.1.5.61', 'hari': 'Senin', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 32}
# {'id_slot': 50, 'id_mk': 211840330, 'mata_kuliah': 'Interaksi Manusia dan Komputer', 'id_dosen': 13, 'dosen': 'Dwi Normawati, S.T., M.Eng', 'ruang': '4.1.5.61', 'hari': 'Senin', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 32}
# {'id_slot': 51, 'id_mk': 211840330, 'mata_kuliah': 'Interaksi Manusia dan Komputer', 'id_dosen': 13, 'dosen': 'Dwi Normawati, S.T., M.Eng', 'ruang': '4.1.5.61', 'hari': 'Senin', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 32}
# {'id_slot': 52, 'id_mk': 211840711, 'mata_kuliah': 'Praktikum Komunikasi Data dan Jaringan Komputer', 'id_dosen': 34, 'dosen': 'Taufiq Ismail, S.T., M.Cs.', 'ruang': '4.1.5.61', 'hari': 'Senin', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': 'D', 'sks': 1, 'metode': 'Offline', 'temp_id': 96}
# {'id_slot': 53, 'id_mk': 211840630, 'mata_kuliah': 'Komunikasi Data dan Jaringan Komputer', 'id_dosen': 27, 'dosen': 'Muslihudin, S.T., M.T.', 'ruang': '4.1.5.61', 'hari': 'Senin', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 71}
# {'id_slot': 54, 'id_mk': 211840630, 'mata_kuliah': 'Komunikasi Data dan Jaringan Komputer', 'id_dosen': 27, 'dosen': 'Muslihudin, S.T., M.T.', 'ruang': '4.1.5.61', 'hari': 'Senin', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 71}
# {'id_slot': 55, 'id_mk': 211840630, 'mata_kuliah': 'Komunikasi Data dan Jaringan Komputer', 'id_dosen': 27, 'dosen': 'Muslihudin, S.T., M.T.', 'ruang': '4.1.5.61', 'hari': 'Senin', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 71}
# {'id_slot': 56, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.61', 'hari': 'Senin', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 57, 'id_mk': 211840831, 'mata_kuliah': 'Strategi Algoritma', 'id_dosen': 7, 'dosen': 'Ardi Pujiyanta, Dr., Ir., M.T.', 'ruang': '4.1.5.61', 'hari': 'Senin', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 14}
# {'id_slot': 58, 'id_mk': 211840831, 'mata_kuliah': 'Strategi Algoritma', 'id_dosen': 7, 'dosen': 'Ardi Pujiyanta, Dr., Ir., M.T.', 'ruang': '4.1.5.61', 'hari': 'Senin', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 14}
# {'id_slot': 59, 'id_mk': 211840831, 'mata_kuliah': 'Strategi Algoritma', 'id_dosen': 7, 'dosen': 'Ardi Pujiyanta, Dr., Ir., M.T.', 'ruang': '4.1.5.61', 'hari': 'Senin', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 14}
# {'id_slot': 60, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.61', 'hari': 'Senin', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 61, 'id_mk': 211840630, 'mata_kuliah': 'Komunikasi Data dan Jaringan Komputer', 'id_dosen': 28, 'dosen': 'Nuril Anwar, S.T., M.Kom.', 'ruang': '4.1.5.62', 'hari': 'Senin', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 75}
# {'id_slot': 62, 'id_mk': 211840630, 'mata_kuliah': 'Komunikasi Data dan Jaringan Komputer', 'id_dosen': 28, 'dosen': 'Nuril Anwar, S.T., M.Kom.', 'ruang': '4.1.5.62', 'hari': 'Senin', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 75}
# {'id_slot': 63, 'id_mk': 211840630, 'mata_kuliah': 'Komunikasi Data dan Jaringan Komputer', 'id_dosen': 28, 'dosen': 'Nuril Anwar, S.T., M.Kom.', 'ruang': '4.1.5.62', 'hari': 'Senin', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 75}
# {'id_slot': 64, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Senin', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 65, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Senin', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 66, 'id_mk': 211820320, 'mata_kuliah': 'Aljabar Linear Matrik', 'id_dosen': 15, 'dosen': 'Faisal Fajri Rahani, S.Si., M.Cs.', 'ruang': '4.1.5.62', 'hari': 'Senin', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': 'B', 'sks': 2, 'metode': 'Offline', 'temp_id': 37}
# {'id_slot': 67, 'id_mk': 211820320, 'mata_kuliah': 'Aljabar Linear Matrik', 'id_dosen': 15, 'dosen': 'Faisal Fajri Rahani, S.Si., M.Cs.', 'ruang': '4.1.5.62', 'hari': 'Senin', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': 'B', 'sks': 2, 'metode': 'Offline', 'temp_id': 37}
# {'id_slot': 68, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Senin', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 69, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Senin', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 70, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Senin', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 71, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Senin', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 72, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Senin', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 73, 'id_mk': 211830641, 'mata_kuliah': 'Statistika Informatika', 'id_dosen': 21, 'dosen': 'Lisna Zahrotun, S.T., M.Cs', 'ruang': '4.1.5.63', 'hari': 'Senin', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': 'A', 'sks': 4, 'metode': 'Online', 'temp_id': 55}
# {'id_slot': 74, 'id_mk': 211830641, 'mata_kuliah': 'Statistika Informatika', 'id_dosen': 21, 'dosen': 'Lisna Zahrotun, S.T., M.Cs', 'ruang': '4.1.5.63', 'hari': 'Senin', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': 'A', 'sks': 4, 'metode': 'Online', 'temp_id': 55}
# {'id_slot': 75, 'id_mk': 211830641, 'mata_kuliah': 'Statistika Informatika', 'id_dosen': 21, 'dosen': 'Lisna Zahrotun, S.T., M.Cs', 'ruang': '4.1.5.63', 'hari': 'Senin', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': 'A', 'sks': 4, 'metode': 'Online', 'temp_id': 55}
# {'id_slot': 76, 'id_mk': 211830641, 'mata_kuliah': 'Statistika Informatika', 'id_dosen': 21, 'dosen': 'Lisna Zahrotun, S.T., M.Cs', 'ruang': '4.1.5.63', 'hari': 'Senin', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': 'A', 'sks': 4, 'metode': 'Online', 'temp_id': 55}
# {'id_slot': 77, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Senin', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 78, 'id_mk': 211850331, 'mata_kuliah': 'Pemrograman Mobile', 'id_dosen': 19, 'dosen': 'Ika Arfiani, S.T., M.Cs.', 'ruang': '4.1.5.63', 'hari': 'Senin', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': 'A', 'sks': 3, 'metode': 'Online', 'temp_id': 51}
# {'id_slot': 79, 'id_mk': 211850331, 'mata_kuliah': 'Pemrograman Mobile', 'id_dosen': 19, 'dosen': 'Ika Arfiani, S.T., M.Cs.', 'ruang': '4.1.5.63', 'hari': 'Senin', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': 'A', 'sks': 3, 'metode': 'Online', 'temp_id': 51}
# {'id_slot': 80, 'id_mk': 211850331, 'mata_kuliah': 'Pemrograman Mobile', 'id_dosen': 19, 'dosen': 'Ika Arfiani, S.T., M.Cs.', 'ruang': '4.1.5.63', 'hari': 'Senin', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': 'A', 'sks': 3, 'metode': 'Online', 'temp_id': 51}
# {'id_slot': 81, 'id_mk': 211860120, 'mata_kuliah': 'Manajemen Proyek Teknologi Informasi', 'id_dosen': 29, 'dosen': 'Nur Rochmah Dyah Puji Astuti, S.T., M.Kom.', 'ruang': '4.1.5.63', 'hari': 'Senin', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': 'E', 'sks': 2, 'metode': 'Online', 'temp_id': 81}
# {'id_slot': 82, 'id_mk': 211860120, 'mata_kuliah': 'Manajemen Proyek Teknologi Informasi', 'id_dosen': 29, 'dosen': 'Nur Rochmah Dyah Puji Astuti, S.T., M.Kom.', 'ruang': '4.1.5.63', 'hari': 'Senin', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': 'E', 'sks': 2, 'metode': 'Online', 'temp_id': 81}
# {'id_slot': 83, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Senin', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 84, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Senin', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 85, 'id_mk': 211840330, 'mata_kuliah': 'Interaksi Manusia dan Komputer', 'id_dosen': 25, 'dosen': 'Murein Miksa Mardhia, S.T., M.T.', 'ruang': '4.1.5.55', 'hari': 'Selasa', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 65}
# {'id_slot': 86, 'id_mk': 211840330, 'mata_kuliah': 'Interaksi Manusia dan Komputer', 'id_dosen': 25, 'dosen': 'Murein Miksa Mardhia, S.T., M.T.', 'ruang': '4.1.5.55', 'hari': 'Selasa', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 65}
# {'id_slot': 87, 'id_mk': 211840330, 'mata_kuliah': 'Interaksi Manusia dan Komputer', 'id_dosen': 25, 'dosen': 'Murein Miksa Mardhia, S.T., M.T.', 'ruang': '4.1.5.55', 'hari': 'Selasa', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 65}
# {'id_slot': 88, 'id_mk': 211861531, 'mata_kuliah': 'Penglihatan Komputer', 'id_dosen': 15, 'dosen': 'Faisal Fajri Rahani, S.Si., M.Cs.', 'ruang': '4.1.5.55', 'hari': 'Selasa', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': 'A', 'sks': 3, 'metode': 'Online', 'temp_id': 36}
# {'id_slot': 89, 'id_mk': 211861531, 'mata_kuliah': 'Penglihatan Komputer', 'id_dosen': 15, 'dosen': 'Faisal Fajri Rahani, S.Si., M.Cs.', 'ruang': '4.1.5.55', 'hari': 'Selasa', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': 'A', 'sks': 3, 'metode': 'Online', 'temp_id': 36}
# {'id_slot': 90, 'id_mk': 211861531, 'mata_kuliah': 'Penglihatan Komputer', 'id_dosen': 15, 'dosen': 'Faisal Fajri Rahani, S.Si., M.Cs.', 'ruang': '4.1.5.55', 'hari': 'Selasa', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': 'A', 'sks': 3, 'metode': 'Online', 'temp_id': 36}
# {'id_slot': 91, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Selasa', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 92, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Selasa', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 93, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Selasa', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 94, 'id_mk': 211820430, 'mata_kuliah': 'Arsitektur Komputer', 'id_dosen': 20, 'dosen': 'Jefree Fahana, S.T., M.Kom.', 'ruang': '4.1.5.55', 'hari': 'Selasa', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 54}
# {'id_slot': 95, 'id_mk': 211820430, 'mata_kuliah': 'Arsitektur Komputer', 'id_dosen': 20, 'dosen': 'Jefree Fahana, S.T., M.Kom.', 'ruang': '4.1.5.55', 'hari': 'Selasa', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 54}
# {'id_slot': 96, 'id_mk': 211820430, 'mata_kuliah': 'Arsitektur Komputer', 'id_dosen': 20, 'dosen': 'Jefree Fahana, S.T., M.Kom.', 'ruang': '4.1.5.55', 'hari': 'Selasa', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 54}
# {'id_slot': 97, 'id_mk': 211860631, 'mata_kuliah': 'Kriptografi', 'id_dosen': 29, 'dosen': 'Nur Rochmah Dyah Puji Astuti, S.T., M.Kom.', 'ruang': '4.1.5.57', 'hari': 'Selasa', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 79}
# {'id_slot': 98, 'id_mk': 211860631, 'mata_kuliah': 'Kriptografi', 'id_dosen': 29, 'dosen': 'Nur Rochmah Dyah Puji Astuti, S.T., M.Kom.', 'ruang': '4.1.5.57', 'hari': 'Selasa', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 79}
# {'id_slot': 99, 'id_mk': 211860631, 'mata_kuliah': 'Kriptografi', 'id_dosen': 29, 'dosen': 'Nur Rochmah Dyah Puji Astuti, S.T., M.Kom.', 'ruang': '4.1.5.57', 'hari': 'Selasa', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 79}
# {'id_slot': 100, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.57', 'hari': 'Selasa', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 101, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.57', 'hari': 'Selasa', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 102, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.57', 'hari': 'Selasa', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 103, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.57', 'hari': 'Selasa', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 104, 'id_mk': 211860220, 'mata_kuliah': 'Metodologi Penelitian', 'id_dosen': 21, 'dosen': 'Lisna Zahrotun, S.T., M.Cs', 'ruang': '4.1.5.57', 'hari': 'Selasa', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': 'D', 'sks': 2, 'metode': 'Online', 'temp_id': 57}
# {'id_slot': 105, 'id_mk': 211860220, 'mata_kuliah': 'Metodologi Penelitian', 'id_dosen': 21, 'dosen': 'Lisna Zahrotun, S.T., M.Cs', 'ruang': '4.1.5.57', 'hari': 'Selasa', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': 'D', 'sks': 2, 'metode': 'Online', 'temp_id': 57}
# {'id_slot': 106, 'id_mk': 211860831, 'mata_kuliah': 'Sistem Informasi Geografis', 'id_dosen': 19, 'dosen': 'Ika Arfiani, S.T., M.Cs.', 'ruang': '4.1.5.57', 'hari': 'Selasa', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 50}
# {'id_slot': 107, 'id_mk': 211860831, 'mata_kuliah': 'Sistem Informasi Geografis', 'id_dosen': 19, 'dosen': 'Ika Arfiani, S.T., M.Cs.', 'ruang': '4.1.5.57', 'hari': 'Selasa', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 50}
# {'id_slot': 108, 'id_mk': 211860831, 'mata_kuliah': 'Sistem Informasi Geografis', 'id_dosen': 19, 'dosen': 'Ika Arfiani, S.T., M.Cs.', 'ruang': '4.1.5.57', 'hari': 'Selasa', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 50}
# {'id_slot': 109, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.59', 'hari': 'Selasa', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 110, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.59', 'hari': 'Selasa', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 111, 'id_mk': 211860120, 'mata_kuliah': 'Manajemen Proyek Teknologi Informasi', 'id_dosen': 28, 'dosen': 'Nuril Anwar, S.T., M.Kom.', 'ruang': '4.1.5.59', 'hari': 'Selasa', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': 'F', 'sks': 2, 'metode': 'Online', 'temp_id': 76}
# {'id_slot': 112, 'id_mk': 211860120, 'mata_kuliah': 'Manajemen Proyek Teknologi Informasi', 'id_dosen': 28, 'dosen': 'Nuril Anwar, S.T., M.Kom.', 'ruang': '4.1.5.59', 'hari': 'Selasa', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': 'F', 'sks': 2, 'metode': 'Online', 'temp_id': 76}
# {'id_slot': 113, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.59', 'hari': 'Selasa', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 114, 'id_mk': 211861131, 'mata_kuliah': 'Deep learning', 'id_dosen': 26, 'dosen': 'Murinto, Dr., S.Si., M.Kom.', 'ruang': '4.1.5.59', 'hari': 'Selasa', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 69}
# {'id_slot': 115, 'id_mk': 211861131, 'mata_kuliah': 'Deep learning', 'id_dosen': 26, 'dosen': 'Murinto, Dr., S.Si., M.Kom.', 'ruang': '4.1.5.59', 'hari': 'Selasa', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 69}
# {'id_slot': 116, 'id_mk': 211861131, 'mata_kuliah': 'Deep learning', 'id_dosen': 26, 'dosen': 'Murinto, Dr., S.Si., M.Kom.', 'ruang': '4.1.5.59', 'hari': 'Selasa', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 69}
# {'id_slot': 117, 'id_mk': 211850520, 'mata_kuliah': 'Teori Bahasa Otomata', 'id_dosen': 35, 'dosen': 'Tedy Setiadi, Drs., M.T.', 'ruang': '4.1.5.59', 'hari': 'Selasa', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': 'A', 'sks': 2, 'metode': 'Online', 'temp_id': 101}
# {'id_slot': 118, 'id_mk': 211850520, 'mata_kuliah': 'Teori Bahasa Otomata', 'id_dosen': 35, 'dosen': 'Tedy Setiadi, Drs., M.T.', 'ruang': '4.1.5.59', 'hari': 'Selasa', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': 'A', 'sks': 2, 'metode': 'Online', 'temp_id': 101}
# {'id_slot': 119, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.59', 'hari': 'Selasa', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 120, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.59', 'hari': 'Selasa', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 121, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.60', 'hari': 'Selasa', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 122, 'id_mk': 211860531, 'mata_kuliah': 'Keamanan Informasi', 'id_dosen': 28, 'dosen': 'Nuril Anwar, S.T., M.Kom.', 'ruang': '4.1.5.60', 'hari': 'Selasa', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': 'A', 'sks': 3, 'metode': 'Online', 'temp_id': 74}
# {'id_slot': 123, 'id_mk': 211860531, 'mata_kuliah': 'Keamanan Informasi', 'id_dosen': 28, 'dosen': 'Nuril Anwar, S.T., M.Kom.', 'ruang': '4.1.5.60', 'hari': 'Selasa', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': 'A', 'sks': 3, 'metode': 'Online', 'temp_id': 74}
# {'id_slot': 124, 'id_mk': 211860531, 'mata_kuliah': 'Keamanan Informasi', 'id_dosen': 28, 'dosen': 'Nuril Anwar, S.T., M.Kom.', 'ruang': '4.1.5.60', 'hari': 'Selasa', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': 'A', 'sks': 3, 'metode': 'Online', 'temp_id': 74}
# {'id_slot': 125, 'id_mk': 211861431, 'mata_kuliah': 'Pengenalan Pola ', 'id_dosen': 2, 'dosen': 'Ahmad Azhari, S.Kom., M.Eng', 'ruang': '4.1.5.60', 'hari': 'Selasa', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': 'A', 'sks': 3, 'metode': 'Online', 'temp_id': 3}
# {'id_slot': 126, 'id_mk': 211861431, 'mata_kuliah': 'Pengenalan Pola ', 'id_dosen': 2, 'dosen': 'Ahmad Azhari, S.Kom., M.Eng', 'ruang': '4.1.5.60', 'hari': 'Selasa', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': 'A', 'sks': 3, 'metode': 'Online', 'temp_id': 3}
# {'id_slot': 127, 'id_mk': 211861431, 'mata_kuliah': 'Pengenalan Pola ', 'id_dosen': 2, 'dosen': 'Ahmad Azhari, S.Kom., M.Eng', 'ruang': '4.1.5.60', 'hari': 'Selasa', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': 'A', 'sks': 3, 'metode': 'Online', 'temp_id': 3}
# {'id_slot': 128, 'id_mk': 211860831, 'mata_kuliah': 'Sistem Informasi Geografis', 'id_dosen': 21, 'dosen': 'Lisna Zahrotun, S.T., M.Cs', 'ruang': '4.1.5.60', 'hari': 'Selasa', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 58}
# {'id_slot': 129, 'id_mk': 211860831, 'mata_kuliah': 'Sistem Informasi Geografis', 'id_dosen': 21, 'dosen': 'Lisna Zahrotun, S.T., M.Cs', 'ruang': '4.1.5.60', 'hari': 'Selasa', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 58}
# {'id_slot': 130, 'id_mk': 211860831, 'mata_kuliah': 'Sistem Informasi Geografis', 'id_dosen': 21, 'dosen': 'Lisna Zahrotun, S.T., M.Cs', 'ruang': '4.1.5.60', 'hari': 'Selasa', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 58}
# {'id_slot': 131, 'id_mk': 211860220, 'mata_kuliah': 'Metodologi Penelitian', 'id_dosen': 8, 'dosen': 'Arfiani Nur Khusna, S.T., M.Kom.', 'ruang': '4.1.5.60', 'hari': 'Selasa', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': 'B', 'sks': 2, 'metode': 'Online', 'temp_id': 18}
# {'id_slot': 132, 'id_mk': 211860220, 'mata_kuliah': 'Metodologi Penelitian', 'id_dosen': 8, 'dosen': 'Arfiani Nur Khusna, S.T., M.Kom.', 'ruang': '4.1.5.60', 'hari': 'Selasa', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': 'B', 'sks': 2, 'metode': 'Online', 'temp_id': 18}
# {'id_slot': 133, 'id_mk': 211860330, 'mata_kuliah': 'Rekayasa Perangkat Lunak', 'id_dosen': 3, 'dosen': 'Ali Tarmuji, S.T., M.Cs.', 'ruang': '4.1.5.61', 'hari': 'Selasa', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 5}
# {'id_slot': 134, 'id_mk': 211860330, 'mata_kuliah': 'Rekayasa Perangkat Lunak', 'id_dosen': 3, 'dosen': 'Ali Tarmuji, S.T., M.Cs.', 'ruang': '4.1.5.61', 'hari': 'Selasa', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 5}
# {'id_slot': 135, 'id_mk': 211860330, 'mata_kuliah': 'Rekayasa Perangkat Lunak', 'id_dosen': 3, 'dosen': 'Ali Tarmuji, S.T., M.Cs.', 'ruang': '4.1.5.61', 'hari': 'Selasa', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 5}
# {'id_slot': 136, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.61', 'hari': 'Selasa', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 137, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.61', 'hari': 'Selasa', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 138, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.61', 'hari': 'Selasa', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 139, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.61', 'hari': 'Selasa', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 140, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.61', 'hari': 'Selasa', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 141, 'id_mk': 211860731, 'mata_kuliah': 'Rekayasa Web', 'id_dosen': 33, 'dosen': 'Supriyanto, S.T., M.T.', 'ruang': '4.1.5.61', 'hari': 'Selasa', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 94}
# {'id_slot': 142, 'id_mk': 211860731, 'mata_kuliah': 'Rekayasa Web', 'id_dosen': 33, 'dosen': 'Supriyanto, S.T., M.T.', 'ruang': '4.1.5.61', 'hari': 'Selasa', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 94}
# {'id_slot': 143, 'id_mk': 211860731, 'mata_kuliah': 'Rekayasa Web', 'id_dosen': 33, 'dosen': 'Supriyanto, S.T., M.T.', 'ruang': '4.1.5.61', 'hari': 'Selasa', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': 'C', 'sks': 3, 'metode': 'Offline', 'temp_id': 94}
# {'id_slot': 144, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.61', 'hari': 'Selasa', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 145, 'id_mk': 211860330, 'mata_kuliah': 'Rekayasa Perangkat Lunak', 'id_dosen': 6, 'dosen': 'Ardiansyah, Dr., S.T., M.Cs.', 'ruang': '4.1.5.62', 'hari': 'Selasa', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 11}
# {'id_slot': 146, 'id_mk': 211860330, 'mata_kuliah': 'Rekayasa Perangkat Lunak', 'id_dosen': 6, 'dosen': 'Ardiansyah, Dr., S.T., M.Cs.', 'ruang': '4.1.5.62', 'hari': 'Selasa', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 11}
# {'id_slot': 147, 'id_mk': 211860330, 'mata_kuliah': 'Rekayasa Perangkat Lunak', 'id_dosen': 6, 'dosen': 'Ardiansyah, Dr., S.T., M.Cs.', 'ruang': '4.1.5.62', 'hari': 'Selasa', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': 'B', 'sks': 3, 'metode': 'Offline', 'temp_id': 11}
# {'id_slot': 148, 'id_mk': 211820631, 'mata_kuliah': 'Matematika Diskrit', 'id_dosen': 11, 'dosen': 'Dewi Soyusiawaty, S.T., M.T', 'ruang': '4.1.5.62', 'hari': 'Selasa', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 29}
# {'id_slot': 149, 'id_mk': 211820631, 'mata_kuliah': 'Matematika Diskrit', 'id_dosen': 11, 'dosen': 'Dewi Soyusiawaty, S.T., M.T', 'ruang': '4.1.5.62', 'hari': 'Selasa', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 29}
# {'id_slot': 150, 'id_mk': 211820631, 'mata_kuliah': 'Matematika Diskrit', 'id_dosen': 11, 'dosen': 'Dewi Soyusiawaty, S.T., M.T', 'ruang': '4.1.5.62', 'hari': 'Selasa', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 29}
# {'id_slot': 151, 'id_mk': 211820230, 'mata_kuliah': 'Algoritma Pemrograman', 'id_dosen': 36, 'dosen': 'Wahyu Pujiyono, Drs., M.Kom.', 'ruang': '4.1.5.62', 'hari': 'Selasa', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': 'E', 'sks': 3, 'metode': 'Offline', 'temp_id': 102}
# {'id_slot': 152, 'id_mk': 211820230, 'mata_kuliah': 'Algoritma Pemrograman', 'id_dosen': 36, 'dosen': 'Wahyu Pujiyono, Drs., M.Kom.', 'ruang': '4.1.5.62', 'hari': 'Selasa', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': 'E', 'sks': 3, 'metode': 'Offline', 'temp_id': 102}
# {'id_slot': 153, 'id_mk': 211820230, 'mata_kuliah': 'Algoritma Pemrograman', 'id_dosen': 36, 'dosen': 'Wahyu Pujiyono, Drs., M.Kom.', 'ruang': '4.1.5.62', 'hari': 'Selasa', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': 'E', 'sks': 3, 'metode': 'Offline', 'temp_id': 102}
# {'id_slot': 154, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Selasa', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 155, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Selasa', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 156, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Selasa', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 157, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Selasa', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 158, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Selasa', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 159, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Selasa', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 160, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Selasa', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 161, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Selasa', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 162, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Selasa', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 163, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Selasa', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 164, 'id_mk': 211840630, 'mata_kuliah': 'Komunikasi Data dan Jaringan Komputer', 'id_dosen': 17, 'dosen': 'Guntur  Maulana Zamroni, B.Sc., M.Kom.', 'ruang': '4.1.5.63', 'hari': 'Selasa', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 41}
# {'id_slot': 165, 'id_mk': 211840630, 'mata_kuliah': 'Komunikasi Data dan Jaringan Komputer', 'id_dosen': 17, 'dosen': 'Guntur  Maulana Zamroni, B.Sc., M.Kom.', 'ruang': '4.1.5.63', 'hari': 'Selasa', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 41}
# {'id_slot': 166, 'id_mk': 211840630, 'mata_kuliah': 'Komunikasi Data dan Jaringan Komputer', 'id_dosen': 17, 'dosen': 'Guntur  Maulana Zamroni, B.Sc., M.Kom.', 'ruang': '4.1.5.63', 'hari': 'Selasa', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 41}
# {'id_slot': 167, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Selasa', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 168, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Selasa', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 169, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Rabu', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 170, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Rabu', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 171, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Rabu', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 172, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Rabu', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 173, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Rabu', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 174, 'id_mk': 211860120, 'mata_kuliah': 'Manajemen Proyek Teknologi Informasi', 'id_dosen': 11, 'dosen': 'Dewi Soyusiawaty, S.T., M.T', 'ruang': '4.1.5.55', 'hari': 'Rabu', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': 'B', 'sks': 2, 'metode': 'Online', 'temp_id': 27}
# {'id_slot': 175, 'id_mk': 211860120, 'mata_kuliah': 'Manajemen Proyek Teknologi Informasi', 'id_dosen': 11, 'dosen': 'Dewi Soyusiawaty, S.T., M.T', 'ruang': '4.1.5.55', 'hari': 'Rabu', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': 'B', 'sks': 2, 'metode': 'Online', 'temp_id': 27}
# {'id_slot': 176, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Rabu', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 177, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Rabu', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 178, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Rabu', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 179, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Rabu', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 180, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.55', 'hari': 'Rabu', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# ...
# {'id_slot': 444, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.57', 'hari': 'Sabtu', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 445, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.59', 'hari': 'Sabtu', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 446, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.59', 'hari': 'Sabtu', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 447, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.59', 'hari': 'Sabtu', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 448, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.59', 'hari': 'Sabtu', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 449, 'id_mk': 211840131, 'mata_kuliah': 'Analisis dan Perancangan Perangkat Lunak', 'id_dosen': 35, 'dosen': 'Tedy Setiadi, Drs., M.T.', 'ruang': '4.1.5.59', 'hari': 'Sabtu', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': 'E', 'sks': 3, 'metode': 'Offline', 'temp_id': 100}
# {'id_slot': 450, 'id_mk': 211840131, 'mata_kuliah': 'Analisis dan Perancangan Perangkat Lunak', 'id_dosen': 35, 'dosen': 'Tedy Setiadi, Drs., M.T.', 'ruang': '4.1.5.59', 'hari': 'Sabtu', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': 'E', 'sks': 3, 'metode': 'Offline', 'temp_id': 100}
# {'id_slot': 451, 'id_mk': 211840131, 'mata_kuliah': 'Analisis dan Perancangan Perangkat Lunak', 'id_dosen': 35, 'dosen': 'Tedy Setiadi, Drs., M.T.', 'ruang': '4.1.5.59', 'hari': 'Sabtu', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': 'E', 'sks': 3, 'metode': 'Offline', 'temp_id': 100}
# {'id_slot': 452, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.59', 'hari': 'Sabtu', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 453, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.59', 'hari': 'Sabtu', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 454, 'id_mk': 211860631, 'mata_kuliah': 'Kriptografi', 'id_dosen': 14, 'dosen': 'Eko Aribowo, S.T., M.Kom.', 'ruang': '4.1.5.59', 'hari': 'Sabtu', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 34}
# {'id_slot': 455, 'id_mk': 211860631, 'mata_kuliah': 'Kriptografi', 'id_dosen': 14, 'dosen': 'Eko Aribowo, S.T., M.Kom.', 'ruang': '4.1.5.59', 'hari': 'Sabtu', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 34}
# {'id_slot': 456, 'id_mk': 211860631, 'mata_kuliah': 'Kriptografi', 'id_dosen': 14, 'dosen': 'Eko Aribowo, S.T., M.Kom.', 'ruang': '4.1.5.59', 'hari': 'Sabtu', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 34}
# {'id_slot': 457, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.60', 'hari': 'Sabtu', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 458, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.60', 'hari': 'Sabtu', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 459, 'id_mk': 211850420, 'mata_kuliah': 'Pengantar Manajemen dan Prinsip Proyek', 'id_dosen': 17, 'dosen': 'Guntur  Maulana Zamroni, B.Sc., M.Kom.', 'ruang': '4.1.5.60', 'hari': 'Sabtu', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': 'A', 'sks': 2, 'metode': 'Online', 'temp_id': 45}
# {'id_slot': 460, 'id_mk': 211850420, 'mata_kuliah': 'Pengantar Manajemen dan Prinsip Proyek', 'id_dosen': 17, 'dosen': 'Guntur  Maulana Zamroni, B.Sc., M.Kom.', 'ruang': '4.1.5.60', 'hari': 'Sabtu', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': 'A', 'sks': 2, 'metode': 'Online', 'temp_id': 45}
# {'id_slot': 461, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.60', 'hari': 'Sabtu', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 462, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.60', 'hari': 'Sabtu', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 463, 'id_mk': 211860931, 'mata_kuliah': 'Sistem terdistribusi', 'id_dosen': 31, 'dosen': 'Sheraton Pawestri, S.Kom., M.Cs.', 'ruang': '4.1.5.60', 'hari': 'Sabtu', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': 'B', 'sks': 3, 'metode': 'Online', 'temp_id': 85}
# {'id_slot': 464, 'id_mk': 211860931, 'mata_kuliah': 'Sistem terdistribusi', 'id_dosen': 31, 'dosen': 'Sheraton Pawestri, S.Kom., M.Cs.', 'ruang': '4.1.5.60', 'hari': 'Sabtu', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': 'B', 'sks': 3, 'metode': 'Online', 'temp_id': 85}
# {'id_slot': 465, 'id_mk': 211860931, 'mata_kuliah': 'Sistem terdistribusi', 'id_dosen': 31, 'dosen': 'Sheraton Pawestri, S.Kom., M.Cs.', 'ruang': '4.1.5.60', 'hari': 'Sabtu', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': 'B', 'sks': 3, 'metode': 'Online', 'temp_id': 85}
# {'id_slot': 466, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.60', 'hari': 'Sabtu', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 467, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.60', 'hari': 'Sabtu', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 468, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.60', 'hari': 'Sabtu', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 469, 'id_mk': 211820320, 'mata_kuliah': 'Aljabar Linear Matrik', 'id_dosen': 17, 'dosen': 'Guntur  Maulana Zamroni, B.Sc., M.Kom.', 'ruang': '4.1.5.61', 'hari': 'Sabtu', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': 'A', 'sks': 2, 'metode': 'Offline', 'temp_id': 43}
# {'id_slot': 470, 'id_mk': 211820320, 'mata_kuliah': 'Aljabar Linear Matrik', 'id_dosen': 17, 'dosen': 'Guntur  Maulana Zamroni, B.Sc., M.Kom.', 'ruang': '4.1.5.61', 'hari': 'Sabtu', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': 'A', 'sks': 2, 'metode': 'Offline', 'temp_id': 43}
# {'id_slot': 471, 'id_mk': 211860220, 'mata_kuliah': 'Metodologi Penelitian', 'id_dosen': 26, 'dosen': 'Murinto, Dr., S.Si., M.Kom.', 'ruang': '4.1.5.61', 'hari': 'Sabtu', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': 'E', 'sks': 2, 'metode': 'Online', 'temp_id': 67}
# {'id_slot': 472, 'id_mk': 211860220, 'mata_kuliah': 'Metodologi Penelitian', 'id_dosen': 26, 'dosen': 'Murinto, Dr., S.Si., M.Kom.', 'ruang': '4.1.5.61', 'hari': 'Sabtu', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': 'E', 'sks': 2, 'metode': 'Online', 'temp_id': 67}
# {'id_slot': 473, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.61', 'hari': 'Sabtu', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 474, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.61', 'hari': 'Sabtu', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 475, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.61', 'hari': 'Sabtu', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 476, 'id_mk': 211820731, 'mata_kuliah': 'Pemrograman Web', 'id_dosen': 3, 'dosen': 'Ali Tarmuji, S.T., M.Cs.', 'ruang': '4.1.5.61', 'hari': 'Sabtu', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 6}
# {'id_slot': 477, 'id_mk': 211820731, 'mata_kuliah': 'Pemrograman Web', 'id_dosen': 3, 'dosen': 'Ali Tarmuji, S.T., M.Cs.', 'ruang': '4.1.5.61', 'hari': 'Sabtu', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 6}
# {'id_slot': 478, 'id_mk': 211820731, 'mata_kuliah': 'Pemrograman Web', 'id_dosen': 3, 'dosen': 'Ali Tarmuji, S.T., M.Cs.', 'ruang': '4.1.5.61', 'hari': 'Sabtu', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': 'A', 'sks': 3, 'metode': 'Offline', 'temp_id': 6}
# {'id_slot': 479, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.61', 'hari': 'Sabtu', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 480, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.61', 'hari': 'Sabtu', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 481, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Sabtu', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 482, 'id_mk': 211860220, 'mata_kuliah': 'Metodologi Penelitian', 'id_dosen': 33, 'dosen': 'Supriyanto, S.T., M.T.', 'ruang': '4.1.5.62', 'hari': 'Sabtu', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': 'F', 'sks': 2, 'metode': 'Online', 'temp_id': 91}
# {'id_slot': 483, 'id_mk': 211860220, 'mata_kuliah': 'Metodologi Penelitian', 'id_dosen': 33, 'dosen': 'Supriyanto, S.T., M.T.', 'ruang': '4.1.5.62', 'hari': 'Sabtu', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': 'F', 'sks': 2, 'metode': 'Online', 'temp_id': 91}
# {'id_slot': 484, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Sabtu', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 485, 'id_mk': 211840711, 'mata_kuliah': 'Praktikum Komunikasi Data dan Jaringan Komputer', 'id_dosen': 17, 'dosen': 'Guntur  Maulana Zamroni, B.Sc., M.Kom.', 'ruang': '4.1.5.62', 'hari': 'Sabtu', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': 'A', 'sks': 1, 'metode': 'Offline', 'temp_id': 42}
# {'id_slot': 486, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Sabtu', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 487, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Sabtu', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 488, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Sabtu', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 489, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Sabtu', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 490, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Sabtu', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 491, 'id_mk': 211820911, 'mata_kuliah': 'Praktikum Algoritma Pemrograman', 'id_dosen': 36, 'dosen': 'Wahyu Pujiyono, Drs., M.Kom.', 'ruang': '4.1.5.62', 'hari': 'Sabtu', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': 'E', 'sks': 1, 'metode': 'Offline', 'temp_id': 103}
# {'id_slot': 492, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.62', 'hari': 'Sabtu', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 493, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Sabtu', 'jam_mulai': '7:00:00', 'jam_selesai': '7:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 494, 'id_mk': 211840630, 'mata_kuliah': 'Komunikasi Data dan Jaringan Komputer', 'id_dosen': 34, 'dosen': 'Taufiq Ismail, S.T., M.Cs.', 'ruang': '4.1.5.63', 'hari': 'Sabtu', 'jam_mulai': '7:50:00', 'jam_selesai': '8:45:00', 'kelas': 'D', 'sks': 3, 'metode': 'Offline', 'temp_id': 97}
# {'id_slot': 495, 'id_mk': 211840630, 'mata_kuliah': 'Komunikasi Data dan Jaringan Komputer', 'id_dosen': 34, 'dosen': 'Taufiq Ismail, S.T., M.Cs.', 'ruang': '4.1.5.63', 'hari': 'Sabtu', 'jam_mulai': '8:45:00', 'jam_selesai': '9:35:00', 'kelas': 'D', 'sks': 3, 'metode': 'Offline', 'temp_id': 97}
# {'id_slot': 496, 'id_mk': 211840630, 'mata_kuliah': 'Komunikasi Data dan Jaringan Komputer', 'id_dosen': 34, 'dosen': 'Taufiq Ismail, S.T., M.Cs.', 'ruang': '4.1.5.63', 'hari': 'Sabtu', 'jam_mulai': '9:35:00', 'jam_selesai': '10:25:00', 'kelas': 'D', 'sks': 3, 'metode': 'Offline', 'temp_id': 97}
# {'id_slot': 497, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Sabtu', 'jam_mulai': '10:30:00', 'jam_selesai': '11:20:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 498, 'id_mk': 211820320, 'mata_kuliah': 'Aljabar Linear Matrik', 'id_dosen': 30, 'dosen': 'Rusydi Umar, S.T., M.T., Ph.D', 'ruang': '4.1.5.63', 'hari': 'Sabtu', 'jam_mulai': '11:20:00', 'jam_selesai': '12:10:00', 'kelas': 'D', 'sks': 2, 'metode': 'Offline', 'temp_id': 82}
# {'id_slot': 499, 'id_mk': 211820320, 'mata_kuliah': 'Aljabar Linear Matrik', 'id_dosen': 30, 'dosen': 'Rusydi Umar, S.T., M.T., Ph.D', 'ruang': '4.1.5.63', 'hari': 'Sabtu', 'jam_mulai': '12:30:00', 'jam_selesai': '13:20:00', 'kelas': 'D', 'sks': 2, 'metode': 'Offline', 'temp_id': 82}
# {'id_slot': 500, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Sabtu', 'jam_mulai': '13:20:00', 'jam_selesai': '14:10:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# {'id_slot': 501, 'id_mk': 211820731, 'mata_kuliah': 'Pemrograman Web', 'id_dosen': 33, 'dosen': 'Supriyanto, S.T., M.T.', 'ruang': '4.1.5.63', 'hari': 'Sabtu', 'jam_mulai': '14:15:00', 'jam_selesai': '15:05:00', 'kelas': 'D', 'sks': 3, 'metode': 'Offline', 'temp_id': 93}
# {'id_slot': 502, 'id_mk': 211820731, 'mata_kuliah': 'Pemrograman Web', 'id_dosen': 33, 'dosen': 'Supriyanto, S.T., M.T.', 'ruang': '4.1.5.63', 'hari': 'Sabtu', 'jam_mulai': '15:15:00', 'jam_selesai': '16:05:00', 'kelas': 'D', 'sks': 3, 'metode': 'Offline', 'temp_id': 93}
# {'id_slot': 503, 'id_mk': 211820731, 'mata_kuliah': 'Pemrograman Web', 'id_dosen': 33, 'dosen': 'Supriyanto, S.T., M.T.', 'ruang': '4.1.5.63', 'hari': 'Sabtu', 'jam_mulai': '16:10:00', 'jam_selesai': '17:00:00', 'kelas': 'D', 'sks': 3, 'metode': 'Offline', 'temp_id': 93}
# {'id_slot': 504, 'id_mk': None, 'mata_kuliah': None, 'id_dosen': None, 'dosen': None, 'ruang': '4.1.5.63', 'hari': 'Sabtu', 'jam_mulai': '17:00:00', 'jam_selesai': '17:50:00', 'kelas': None, 'sks': None, 'metode': None, 'temp_id': None}
# Jadwal Sudah Lengkap
# Jumlah slot yang terisi:  282

# %% [markdown]
# Konstrain berat 1
# Konstrain ringan 0.5
#
# Konstrain berat:
# dosen tidak boleh mengajar mata kuliah/kelas berbeda pada jam yang sama
# ruang kelas tidak boleh digunakan lebih dari 1 kelas/dosen
# 3 sks membutuhkan 3 slot waktu
# ruangan antar kelas harus sama
# slot waktu harus berurutan
#
# Konstrain ringan: pereferensi dosen
# dosen Ardiansyah, Dr., S.T., M.Cs. Tidak ingin kelas sebelum 12:00 PM
# dosen Ali Tarmuji, S.T., M.Cs. Tidak ingin ada kelas pada hari Sabtu
# dosen Bambang Robiin, S.T., M.T. tidak ingin kelas setelah 12:00 PM
# dosen Tedy Setiadi, Drs., M.T. Tidak ingin ada kelas pada hari Sabtu dan Kamis

# %%
# Fungsi Fitness dengan Perbaikan
# Fungsi pembantu: Deteksi konflik pada kumpulan interval waktu
def detect_time_conflicts(intervals):
    conflicts = []
    intervals.sort(key=lambda x: x[0])
    for i in range(1, len(intervals)):
        if intervals[i][0] < intervals[i-1][1]:
            conflicts.append((intervals[i-1][2], intervals[i][2]))
    return conflicts

# Fungsi untuk mengambil konfigurasi preferensi dosen
def get_lecturer_preferences():
    return {
        "Ardiansyah, Dr., S.T., M.Cs.": [
            {"type": "time_before", "value": 720}  # Tidak ada kelas sebelum 12:00 PM
        ],
        "Ali Tarmuji, S.T., M.Cs.": [
            {"type": "restricted_day", "value": "sabtu"}  # Tidak ada kelas pada hari Sabtu
        ]
    }

def collect_conflicts(schedule):
    conflict_temp_ids = set()
    lecturer_preferences = get_lecturer_preferences()
    preference_conflict_temp_ids = set()
    
    # --- (A) Konsistensi Ruangan dalam satu temp_id ---
    temp_groups = defaultdict(list)
    for slot in schedule:
        if slot['mata_kuliah'] is not None and slot.get('temp_id') is not None:
            temp_groups[slot['temp_id']].append(slot)
    room_consistency_conflicts = []
    for tid, slots in temp_groups.items():
        ruangan_set = {slot['ruang'] for slot in slots}
        if len(ruangan_set) > 1:
            conflict_temp_ids.add(tid)
            room_consistency_conflicts.append({
                'temp_id': tid,
                'ruangan': list(ruangan_set),
                'slot_ids': [slot['id_slot'] for slot in slots]
            })
    
    # --- (D) Urutan Slot: Temp_id yang sama harus berurutan ---
    sequence_conflicts = []
    for tid, slots in temp_groups.items():
        if len(slots) > 1:
            sorted_slots = sorted(slots, key=lambda s: s['id_slot'])
            expected_ids = list(range(sorted_slots[0]['id_slot'], sorted_slots[0]['id_slot'] + len(sorted_slots)))
            actual_ids = [slot['id_slot'] for slot in sorted_slots]
            if actual_ids != expected_ids:
                conflict_temp_ids.add(tid)
                sequence_conflicts.append({
                    'temp_id': tid,
                    'expected_ids': expected_ids,
                    'actual_ids': actual_ids
                })
    
    # --- (B) Konflik Dosen: Dosen tidak boleh mengajar 2 course berbeda pada jam/hari yang sama ---
    teacher_conflicts = []
    teacher_groups = defaultdict(list)
    for slot in schedule:
        if slot['mata_kuliah'] is None:
            continue
        key = (slot['dosen'], slot['hari'].lower())
        teacher_groups[key].append(slot)
    for (dosen, hari), slots in teacher_groups.items():
        slots.sort(key=lambda s: time_to_minutes(s['jam_mulai']))
        for i in range(len(slots)):
            for j in range(i+1, len(slots)):
                start_i = time_to_minutes(slots[i]['jam_mulai'])
                end_i = time_to_minutes(slots[i]['jam_selesai'])
                start_j = time_to_minutes(slots[j]['jam_mulai'])
                if start_j < end_i and slots[i]['mata_kuliah'] != slots[j]['mata_kuliah']:
                    # Tambahkan temp_id dari kedua slot (jika ada)
                    tid_i = slots[i].get('temp_id')
                    tid_j = slots[j].get('temp_id')
                    if tid_i is not None:
                        conflict_temp_ids.add(tid_i)
                    if tid_j is not None:
                        conflict_temp_ids.add(tid_j)
                    teacher_conflicts.append((slots[i]['id_slot'], slots[j]['id_slot']))
    
    # --- (C) Konflik Ruangan: Ruang yang sama tidak boleh digunakan untuk 2 kelas berbeda pada jam/hari yang sama ---
    room_conflicts = []
    room_groups = defaultdict(list)
    for slot in schedule:
        if slot['mata_kuliah'] is None:
            continue
        key = (slot['ruang'], slot['hari'].lower())
        room_groups[key].append(slot)
    for (ruang, hari), slots in room_groups.items():
        slots.sort(key=lambda s: time_to_minutes(s['jam_mulai']))
        for i in range(len(slots)):
            for j in range(i+1, len(slots)):
                start_i = time_to_minutes(slots[i]['jam_mulai'])
                end_i = time_to_minutes(slots[i]['jam_selesai'])
                start_j = time_to_minutes(slots[j]['jam_mulai'])
                if start_j < end_i and slots[i]['kelas'] != slots[j]['kelas']:
                    tid_i = slots[i].get('temp_id')
                    tid_j = slots[j].get('temp_id')
                    if tid_i is not None:
                        conflict_temp_ids.add(tid_i)
                    if tid_j is not None:
                        conflict_temp_ids.add(tid_j)
                    room_conflicts.append((slots[i]['id_slot'], slots[j]['id_slot']))
    
    # --- Preferensi Dosen: ---
    for slot in schedule:
        if slot['mata_kuliah'] is None:
            continue
        start = time_to_minutes(slot['jam_mulai'])
        tid = slot.get('temp_id')
        dosen = str(slot['dosen'])
        hari = slot['hari'].lower()
        if dosen in lecturer_preferences:
            for pref in lecturer_preferences[dosen]:
                violated = False
                if pref["type"] == "time_before" and start < pref["value"]:
                    violated = True
                elif pref["type"] == "time_after" and start >= pref["value"]:
                    violated = True
                elif pref["type"] == "restricted_day":
                    days = [d.strip() for d in pref["value"].split(',')]
                    if hari in days:
                        violated = True
                if violated and tid is not None:
                    preference_conflict_temp_ids.add(tid)
    
    # --- SKS Conflict: Jumlah slot pada course harus sesuai dengan SKS ---
    sks_conflicts = []
    course_teacher_class = defaultdict(list)
    for slot in schedule:
        if slot['mata_kuliah'] is None:
            continue
        key = (slot['mata_kuliah'], slot['dosen'], slot['kelas'])
        course_teacher_class[key].append(slot)
    for key, slots in course_teacher_class.items():
        expected_slots = slots[0]['sks']
        if len(slots) != expected_slots:
            for s in slots:
                tid = s.get('temp_id')
                if tid is not None:
                    conflict_temp_ids.add(tid)
            sks_conflicts.append({
                'course_key': key,
                'expected': expected_slots,
                'actual': len(slots)
            })
    
    return {
        'conflict_temp_ids': conflict_temp_ids,
        'preference_conflict_temp_ids': preference_conflict_temp_ids,
        'teacher_conflicts': teacher_conflicts,   
        'room_conflicts': room_conflicts,           
        'room_consistency_conflicts': room_consistency_conflicts,  
        'sequence_conflicts': sequence_conflicts,   
        'sks_conflicts': sks_conflicts,
    }

def calculate_fitness(schedule):
    conflicts = collect_conflicts(schedule)
    penalty = 0.0
    # Setiap konflik (berdasarkan temp_id) diberi penalty 1, kecuali preferensi yang diberi 0.5
    penalty += len(conflicts['teacher_conflicts']) * 1.0
    penalty += len(conflicts['room_conflicts']) * 1.0
    penalty += len(conflicts['room_consistency_conflicts']) * 1.0
    penalty += len(conflicts['sequence_conflicts']) * 1.0
    penalty += len(conflicts['sks_conflicts']) * 1.0
    penalty += len(conflicts['preference_conflict_temp_ids']) * 0.5
    # Atau jika ingin menggunakan total conflict_temp_ids:
    # penalty += len(conflicts['conflict_temp_ids']) * 1.0
    return penalty


# Inisialisasi populasi
population_size = 5
population = [create_random_schedule() for _ in range(population_size)]

# Evaluasi fitness untuk setiap individu
for idx, schedule in enumerate(population):
    fitness = calculate_fitness(schedule)
    print(f"\nIndividu {idx+1}:")
    print(f"Total Penalty: {fitness}")
# Out:
# Individu 1:
# Total Penalty: 10.0
#
# Individu 2:
# Total Penalty: 9.0
#
# Individu 3:
# Total Penalty: 9.5
#
# Individu 4:
# Total Penalty: 12.0
#
# Individu 5:
# Total Penalty: 19.5

# %%
class GreyWolfOptimizer:
    def __init__(self, population_size=10, max_iterations=100):
        self.population_size = population_size
        self.max_iterations = max_iterations
        
    def optimize(self, fitness_function, create_solution_function, collect_conflicts_func):
        # Inisialisasi populasi
        population = [create_solution_function() for _ in range(self.population_size)]
        fitness_values = [fitness_function(solution) for solution in population]
        
        best_solution = None
        best_fitness = float('inf')
        a_start = 2.0
        
        for iteration in range(self.max_iterations):
            a = a_start - iteration * (a_start / self.max_iterations)
            if best_fitness <= 0:
                break
            
            sorted_indices = np.argsort(fitness_values)
            alpha = population[sorted_indices[0]]
            beta = population[sorted_indices[1]]
            delta = population[sorted_indices[2]]
            alpha_fitness = fitness_values[sorted_indices[0]]
            
            if alpha_fitness < best_fitness:
                best_fitness = alpha_fitness
                best_solution = copy.deepcopy(alpha)
            
            print(f"Iterasi {iteration+1}/{self.max_iterations} - Best Fitness: {best_fitness}")
            
            new_population = []
            for i in range(self.population_size):
                # Dengan probabilitas kecil lakukan random restart
                if random.random() < 0.05:
                    new_solution = create_solution_function()
                else:
                    new_solution = self.update_position(population[i], alpha, beta, delta, a, create_solution_function, fitness_function)
                new_population.append(new_solution)
                fitness_values[i] = fitness_function(new_solution)
            
            population = new_population
        
        print("Optimasi Selesai!")
        print(f"Best Fitness: {best_fitness}")
        return best_solution, best_fitness
    
    def update_position(self, current_solution, alpha, beta, delta, a, create_solution_function, fitness_function):
        """
        Update posisi serigala dengan fokus pada blok yang mengalami konflik (berdasarkan temp_id).
        Untuk setiap temp_id yang terdeteksi konflik, fungsi akan mencoba terlebih dahulu
        melakukan repair (menjadwalkan ulang kursus) tanpa mengosongkan blok.
        Jika repair berhasil, blok tersebut akan direset dan diperbarui.
        Jika repair gagal, blok asli dipertahankan.
        """
        new_solution = copy.deepcopy(current_solution)
        
        # Dapatkan temp_id yang mengalami konflik dari solusi saat ini
        conflicts = collect_conflicts(new_solution)
        conflict_temp_ids = conflicts.get('conflict_temp_ids', set())
        
        # Jika tidak ada konflik, kembalikan solusi tanpa perubahan
        if not conflict_temp_ids:
            return new_solution
        
        # Fokus pada setiap temp_id yang bermasalah
        for tid in conflict_temp_ids:
            # Dapatkan indeks slot yang memiliki temp_id ini
            indices = [i for i, slot in enumerate(new_solution) if slot.get('temp_id') == tid]
            if not indices:
                continue 
            
            candidate = None
            for source in [alpha, beta, delta]:
                source_block = [slot for slot in source if slot.get('temp_id') == tid]
                if source_block:
                    candidate = source_block[0]
                    break
            
            if candidate is not None:
                course_info = {
                    'mata_kuliah': candidate['mata_kuliah'],
                    'dosen': candidate['dosen'],
                    'kelas': candidate['kelas'],
                    'sks': candidate['sks'],
                    'metode': candidate['metode']
                }
                # Buat salinan sementara dari solusi untuk mencoba repair
                temp_solution = copy.deepcopy(new_solution)
                # Reset blok pada temp_solution
                for idx in indices:
                    temp_solution[idx].update({
                        "mata_kuliah": None,
                        "dosen": None,
                        "kelas": None,
                        "sks": None,
                        "metode": None,
                        "temp_id": None
                    })
                # Coba jadwalkan ulang kursus pada temp_solution dengan opsi relax
                repair_attempts = 5
                success = False
                for _ in range(repair_attempts):
                    if self.schedule_course(temp_solution, course_info, relax=True):
                        success = True
                        break
                if not success:
                    # Jika repair dengan relax gagal, coba dengan force
                    if self.schedule_course(temp_solution, course_info, force=True):
                        success = True
                # Jika berhasil, update new_solution dengan temp_solution untuk blok tersebut
                if success:
                    new_solution = temp_solution
                # Jika tidak berhasil, biarkan blok asli tidak diubah (tidak direset)
        
        return new_solution

    
    def schedule_course(self, schedule, course, force=False, relax=False):
        """
        Menjadwalkan kursus ke dalam slot kosong dengan aturan:
         - Semua slot harus kosong
         - Slot berada di hari yang sama
         - Jika offline, ruangan harus konsisten
         - Slot harus berurutan
        Jika parameter relax True, maka kita lewati beberapa constraint (misalnya, toleransi waktu hingga 5 menit)
        Jika force True, coba masukkan secara global.
        """
        mata_kuliah = course['mata_kuliah']
        dosen = course['dosen']
        kelas = course['kelas']
        sks = course['sks']
        metode = course['metode']
        
        possible_positions = []
        for i in range(len(schedule) - sks + 1):
            block = schedule[i:i+sks]
            if not all(slot['mata_kuliah'] is None for slot in block):
                continue
            if not all(slot['hari'] == block[0]['hari'] for slot in block):
                continue
            if not all(slot['ruang'] == block[0]['ruang'] for slot in block):
                continue

            valid = True
            for j in range(1, len(block)):
                time_diff = abs(time_to_minutes(block[j]['jam_mulai']) - time_to_minutes(block[j-1]['jam_selesai']))
                if not relax and time_diff != 0:
                    valid = False
                    break
                elif relax and time_diff > 5:
                    valid = False
                    break
            if valid:
                possible_positions.append(i)
        
        if possible_positions:
            pos = random.choice(possible_positions)
            block = schedule[pos:pos+sks]
            new_temp_id = random.randint(1000, 1000000)
            for slot in block:
                slot.update({
                    "mata_kuliah": mata_kuliah,
                    "dosen": dosen,
                    "kelas": kelas,
                    "sks": sks,
                    "metode": metode,
                    "temp_id": new_temp_id
                })
            return True
        
        if force and sks == 1:
            empty_slots = [i for i, slot in enumerate(schedule) if slot['mata_kuliah'] is None]
            if empty_slots:
                pos = random.choice(empty_slots)
                schedule[pos].update({
                    "mata_kuliah": mata_kuliah,
                    "dosen": dosen,
                    "kelas": kelas,
                    "sks": sks,
                    "metode": metode,
                    "temp_id": random.randint(1000, 1000000)
                })
                return True
        
        return False

def run_gwo_optimization(create_random_schedule_func, calculate_fitness_func, collect_conflicts_func, population_size=10, max_iterations=100):
    gwo = GreyWolfOptimizer(population_size, max_iterations)
    best_solution, best_fitness = gwo.optimize(calculate_fitness_func, create_random_schedule_func, collect_conflicts_func)
    return best_solution, best_fitness

# ------------------------------------------------------------------
# Pemanggilan utama
if __name__ == "__main__":
    best_schedule, best_fitness = run_gwo_optimization(
        create_random_schedule,
        calculate_fitness,
        collect_conflicts,
        population_size=10,
        max_iterations=50
    )
    
    print(f"Optimasi selesai! Fitness terbaik: {best_fitness}")
    
    total_terisi = sum(1 for slot in best_schedule if slot['mata_kuliah'] is not None)
    print(f"Total slot terisi: {total_terisi}")
    
    total_sks = merged_df['sks'].sum()
    if total_terisi == total_sks:
        print("Jadwal Sudah Lengkap")
    else:
        print("Jadwal Belum Lengkap")
    
    with open('output.json', 'w') as f:
        json.dump(best_schedule, f, indent=4)
# Out:
# Iterasi 1/50 - Best Fitness: 8.5
# Iterasi 2/50 - Best Fitness: 1.5
# Iterasi 3/50 - Best Fitness: 1.5
# Iterasi 4/50 - Best Fitness: 1.5
# Iterasi 5/50 - Best Fitness: 1.5
# Iterasi 6/50 - Best Fitness: 1.5
# Iterasi 7/50 - Best Fitness: 1.5
# Iterasi 8/50 - Best Fitness: 1.5
# Iterasi 9/50 - Best Fitness: 1.5
# Iterasi 10/50 - Best Fitness: 1.5
# Iterasi 11/50 - Best Fitness: 1.0
# Iterasi 12/50 - Best Fitness: 1.0
# Iterasi 13/50 - Best Fitness: 1.0
# Iterasi 14/50 - Best Fitness: 1.0
# Iterasi 15/50 - Best Fitness: 1.0
# Iterasi 16/50 - Best Fitness: 1.0
# Iterasi 17/50 - Best Fitness: 1.0
# Iterasi 18/50 - Best Fitness: 1.0
# Iterasi 19/50 - Best Fitness: 1.0
# Iterasi 20/50 - Best Fitness: 1.0
# Iterasi 21/50 - Best Fitness: 1.0
# Iterasi 22/50 - Best Fitness: 1.0
# Iterasi 23/50 - Best Fitness: 1.0
# Iterasi 24/50 - Best Fitness: 1.0
# Iterasi 25/50 - Best Fitness: 1.0
# Iterasi 26/50 - Best Fitness: 1.0
# Iterasi 27/50 - Best Fitness: 1.0
# Iterasi 28/50 - Best Fitness: 1.0
# Iterasi 29/50 - Best Fitness: 1.0
# Iterasi 30/50 - Best Fitness: 1.0
# Iterasi 31/50 - Best Fitness: 1.0
# Iterasi 32/50 - Best Fitness: 1.0
# Iterasi 33/50 - Best Fitness: 0.5
# Iterasi 34/50 - Best Fitness: 0.5
# Iterasi 35/50 - Best Fitness: 0.5
# Iterasi 36/50 - Best Fitness: 0.5
# Iterasi 37/50 - Best Fitness: 0.5
# Iterasi 38/50 - Best Fitness: 0.5
# Iterasi 39/50 - Best Fitness: 0.5
# Iterasi 40/50 - Best Fitness: 0.5
# Iterasi 41/50 - Best Fitness: 0.5
# Iterasi 42/50 - Best Fitness: 0.5
# Iterasi 43/50 - Best Fitness: 0.5
# Iterasi 44/50 - Best Fitness: 0.5
# Iterasi 45/50 - Best Fitness: 0.5
# Iterasi 46/50 - Best Fitness: 0.5
# Iterasi 47/50 - Best Fitness: 0.5
# Iterasi 48/50 - Best Fitness: 0.5
# Iterasi 49/50 - Best Fitness: 0.5
# Iterasi 50/50 - Best Fitness: 0.5
# Optimasi Selesai!
# Best Fitness: 0.5
# Optimasi selesai! Fitness terbaik: 0.5
# Total slot terisi: 282
# Jadwal Sudah Lengkap
